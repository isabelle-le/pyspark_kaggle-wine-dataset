# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansicyan">  File </span><span class="ansigreen">&quot;&lt;command-3704468688930344&gt;&quot;</span><span class="ansicyan">, line </span><span class="ansigreen">1</span>
# <span class="ansiyellow">    author : Isabelle LE</span>
# <span class="ansigrey">           ^</span>
# <span class="ansired">SyntaxError</span><span class="ansired">:</span> invalid syntax
# </div>

# %%
import pyspark as spark
from pyspark.sql import SparkSession
from pyspark import SparkContext 

from pyspark.sql import functions as f

import matplotlib.pyplot as plt
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark = SparkSession \
        .builder\
        .getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# File location and type
file_location = "/FileStore/tables/winequality_red-42ff5.csv"
file_type = "csv"

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", "true") \
  .option("header", "true") \
  .option("sep", ",") \
  .load(file_location)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fixed acidity</th><th>volatile acidity</th><th>citric acid</th><th>residual sugar</th><th>chlorides</th><th>free sulfur dioxide</th><th>total sulfur dioxide</th><th>density</th><th>pH</th><th>sulphates</th><th>alcohol</th><th>quality</th></tr></thead><tbody><tr><td>7.4</td><td>0.7</td><td>0.0</td><td>1.9</td><td>0.076</td><td>11.0</td><td>34.0</td><td>0.9978</td><td>3.51</td><td>0.56</td><td>9.4</td><td>5</td></tr><tr><td>7.8</td><td>0.88</td><td>0.0</td><td>2.6</td><td>0.098</td><td>25.0</td><td>67.0</td><td>0.9968</td><td>3.2</td><td>0.68</td><td>9.8</td><td>5</td></tr><tr><td>7.8</td><td>0.76</td><td>0.04</td><td>2.3</td><td>0.092</td><td>15.0</td><td>54.0</td><td>0.997</td><td>3.26</td><td>0.65</td><td>9.8</td><td>5</td></tr><tr><td>11.2</td><td>0.28</td><td>0.56</td><td>1.9</td><td>0.075</td><td>17.0</td><td>60.0</td><td>0.998</td><td>3.16</td><td>0.58</td><td>9.8</td><td>6</td></tr><tr><td>7.4</td><td>0.7</td><td>0.0</td><td>1.9</td><td>0.076</td><td>11.0</td><td>34.0</td><td>0.9978</td><td>3.51</td><td>0.56</td><td>9.4</td><td>5</td></tr><tr><td>7.4</td><td>0.66</td><td>0.0</td><td>1.8</td><td>0.075</td><td>13.0</td><td>40.0</td><td>0.9978</td><td>3.51</td><td>0.56</td><td>9.4</td><td>5</td></tr><tr><td>7.9</td><td>0.6</td><td>0.06</td><td>1.6</td><td>0.069</td><td>15.0</td><td>59.0</td><td>0.9964</td><td>3.3</td><td>0.46</td><td>9.4</td><td>5</td></tr><tr><td>7.3</td><td>0.65</td><td>0.0</td><td>1.2</td><td>0.065</td><td>15.0</td><td>21.0</td><td>0.9946</td><td>3.39</td><td>0.47</td><td>10.0</td><td>7</td></tr><tr><td>7.8</td><td>0.58</td><td>0.02</td><td>2.0</td><td>0.073</td><td>9.0</td><td>18.0</td><td>0.9968</td><td>3.36</td><td>0.57</td><td>9.5</td><td>7</td></tr><tr><td>7.5</td><td>0.5</td><td>0.36</td><td>6.1</td><td>0.071</td><td>17.0</td><td>102.0</td><td>0.9978</td><td>3.35</td><td>0.8</td><td>10.5</td><td>5</td></tr><tr><td>6.7</td><td>0.58</td><td>0.08</td><td>1.8</td><td>0.09699999999999999</td><td>15.0</td><td>65.0</td><td>0.9959</td><td>3.28</td><td>0.54</td><td>9.2</td><td>5</td></tr><tr><td>7.5</td><td>0.5</td><td>0.36</td><td>6.1</td><td>0.071</td><td>17.0</td><td>102.0</td><td>0.9978</td><td>3.35</td><td>0.8</td><td>10.5</td><td>5</td></tr><tr><td>5.6</td><td>0.615</td><td>0.0</td><td>1.6</td><td>0.08900000000000001</td><td>16.0</td><td>59.0</td><td>0.9943</td><td>3.58</td><td>0.52</td><td>9.9</td><td>5</td></tr><tr><td>7.8</td><td>0.61</td><td>0.29</td><td>1.6</td><td>0.114</td><td>9.0</td><td>29.0</td><td>0.9974</td><td>3.26</td><td>1.56</td><td>9.1</td><td>5</td></tr><tr><td>8.9</td><td>0.62</td><td>0.18</td><td>3.8</td><td>0.17600000000000002</td><td>52.0</td><td>145.0</td><td>0.9986</td><td>3.16</td><td>0.88</td><td>9.2</td><td>5</td></tr><tr><td>8.9</td><td>0.62</td><td>0.19</td><td>3.9</td><td>0.17</td><td>51.0</td><td>148.0</td><td>0.9986</td><td>3.17</td><td>0.93</td><td>9.2</td><td>5</td></tr><tr><td>8.5</td><td>0.28</td><td>0.56</td><td>1.8</td><td>0.092</td><td>35.0</td><td>103.0</td><td>0.9969</td><td>3.3</td><td>0.75</td><td>10.5</td><td>7</td></tr><tr><td>8.1</td><td>0.56</td><td>0.28</td><td>1.7</td><td>0.368</td><td>16.0</td><td>56.0</td><td>0.9968</td><td>3.11</td><td>1.28</td><td>9.3</td><td>5</td></tr><tr><td>7.4</td><td>0.59</td><td>0.08</td><td>4.4</td><td>0.086</td><td>6.0</td><td>29.0</td><td>0.9974</td><td>3.38</td><td>0.5</td><td>9.0</td><td>4</td></tr><tr><td>7.9</td><td>0.32</td><td>0.51</td><td>1.8</td><td>0.341</td><td>17.0</td><td>56.0</td><td>0.9969</td><td>3.04</td><td>1.08</td><td>9.2</td><td>6</td></tr><tr><td>8.9</td><td>0.22</td><td>0.48</td><td>1.8</td><td>0.077</td><td>29.0</td><td>60.0</td><td>0.9968</td><td>3.39</td><td>0.53</td><td>9.4</td><td>6</td></tr><tr><td>7.6</td><td>0.39</td><td>0.31</td><td>2.3</td><td>0.08199999999999999</td><td>23.0</td><td>71.0</td><td>0.9982</td><td>3.52</td><td>0.65</td><td>9.7</td><td>5</td></tr><tr><td>7.9</td ...

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- fixed acidity: double (nullable = true)
# -- volatile acidity: double (nullable = true)
# -- citric acid: double (nullable = true)
# -- residual sugar: double (nullable = true)
# -- chlorides: double (nullable = true)
# -- free sulfur dioxide: double (nullable = true)
# -- total sulfur dioxide: double (nullable = true)
# -- density: double (nullable = true)
# -- pH: double (nullable = true)
# -- sulphates: double (nullable = true)
# -- alcohol: double (nullable = true)
# -- quality: integer (nullable = true)
#
# </div>

# %%
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">5</span><span class="ansired">]: </span>1599
# </div>

# %%
df.describe('fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide').show()
df.describe('total sulfur dioxide','density','pH','sulphates','alcohol','quality').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------------+-------------------+-------------------+------------------+--------------------+-------------------+
# summary|     fixed acidity|   volatile acidity|        citric acid|    residual sugar|           chlorides|free sulfur dioxide|
# +-------+------------------+-------------------+-------------------+------------------+--------------------+-------------------+
#   count|              1599|               1599|               1599|              1599|                1599|               1599|
#    mean| 8.319637273295838| 0.5278205128205131| 0.2709756097560964|2.5388055034396517| 0.08746654158849257| 15.874921826141339|
#  stddev|1.7410963181276948|0.17905970415353525|0.19480113740531824|  1.40992805950728|0.047065302010090085|  10.46015696980971|
#     min|               4.6|               0.12|                0.0|               0.9|               0.012|                1.0|
#     max|              15.9|               1.58|                1.0|              15.5|               0.611|               72.0|
# +-------+------------------+-------------------+-------------------+------------------+--------------------+-------------------+
#
# +-------+--------------------+--------------------+-------------------+------------------+------------------+------------------+
# summary|total sulfur dioxide|             density|                 pH|         sulphates|           alcohol|           quality|
# +-------+--------------------+--------------------+-------------------+------------------+------------------+------------------+
#   count|                1599|                1599|               1599|              1599|              1599|              1599|
#    mean|   46.46779237023139|  0.9967466791744833|  3.311113195747343|0.6581488430268921|10.422983114446502|5.6360225140712945|
#  stddev|   32.89532447829907|0.001887333953842...|0.15438646490354271|0.1695069795901101|1.0656675818473935|0.8075694397347051|
#     min|                 6.0|  0.9900700000000001|               2.74|              0.33|               8.4|                 3|
#     max|               289.0|             1.00369|               4.01|               2.0|              14.9|                 8|
# +-------+--------------------+--------------------+-------------------+------------------+------------------+------------------+
#
# </div>

# %%
df.summary('25%','75%').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------------+----------------+-----------+--------------+---------+-------------------+--------------------+-------+----+---------+-------+-------+
# summary|fixed acidity|volatile acidity|citric acid|residual sugar|chlorides|free sulfur dioxide|total sulfur dioxide|density|  pH|sulphates|alcohol|quality|
# +-------+-------------+----------------+-----------+--------------+---------+-------------------+--------------------+-------+----+---------+-------+-------+
#     25%|          7.1|            0.39|       0.09|           1.9|     0.07|                7.0|                22.0| 0.9956|3.21|     0.55|    9.5|      5|
#     75%|          9.2|            0.64|       0.42|           2.6|     0.09|               21.0|                62.0|0.99784| 3.4|     0.73|   11.1|      6|
# +-------+-------------+----------------+-----------+--------------+---------+-------------------+--------------------+-------+----+---------+-------+-------+
#
# </div>

# %%
df_stats = df.select(
  f.skewness(f.col('fixed acidity')),
  f.skewness(f.col('volatile acidity')),
  f.skewness(f.col('citric acid')),
  f.skewness(f.col('residual sugar')),
  f.skewness(f.col('chlorides')),
  f.skewness(f.col('free sulfur dioxide')),
  f.skewness(f.col('total sulfur dioxide')),
  f.skewness(f.col('density')),
  f.skewness(f.col('pH')),
  f.skewness(f.col('sulphates')),
  f.skewness(f.col('alcohol')),
  f.skewness(f.col('quality'))
).collect()

print(df_stats)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Row(skewness(fixed acidity)=0.9818292953262083, skewness(volatile acidity)=0.6709623963499571, skewness(citric acid)=0.31803858954753617, skewness(residual sugar)=4.536394788805636, skewness(chlorides)=5.6750165275042646, skewness(free sulfur dioxide)=1.2493938474342596, skewness(total sulfur dioxide)=1.5141091878506623, skewness(density)=0.07122077153539512, skewness(pH)=0.19350175891004878, skewness(sulphates)=2.426393455449086, skewness(alcohol)=0.8600210646566765, skewness(quality)=0.21759720553467232)]
# </div>

# %%
from pyspark.mllib.stat import Statistics
import pandas as pd

features = df.rdd.map(lambda row: row[0:])
corr_map = Statistics.corr(features, method = "pearson")
corr_df = pd.DataFrame(corr_map)
corr_df.index, corr_df.columns = df.columns, df.columns

print(corr_df.to_string())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">                      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide   density        pH  sulphates   alcohol   quality
# fixed acidity              1.000000         -0.256131     0.671703        0.114777   0.093705            -0.153794             -0.113181  0.668047 -0.682978   0.183006 -0.061668  0.124052
# volatile acidity          -0.256131          1.000000    -0.552496        0.001918   0.061298            -0.010504              0.076470  0.022026  0.234937  -0.260987 -0.202288 -0.390558
# citric acid                0.671703         -0.552496     1.000000        0.143577   0.203823            -0.060978              0.035533  0.364947 -0.541904   0.312770  0.109903  0.226373
# residual sugar             0.114777          0.001918     0.143577        1.000000   0.055610             0.187049              0.203028  0.355283 -0.085652   0.005527  0.042075  0.013732
# chlorides                  0.093705          0.061298     0.203823        0.055610   1.000000             0.005562              0.047400  0.200632 -0.265026   0.371260 -0.221141 -0.128907
# free sulfur dioxide       -0.153794         -0.010504    -0.060978        0.187049   0.005562             1.000000              0.667666 -0.021946  0.070377   0.051658 -0.069408 -0.050656
# total sulfur dioxide      -0.113181          0.076470     0.035533        0.203028   0.047400             0.667666              1.000000  0.071269 -0.066495   0.042947 -0.205654 -0.185100
# density                    0.668047          0.022026     0.364947        0.355283   0.200632            -0.021946              0.071269  1.000000 -0.341699   0.148506 -0.496180 -0.174919
# pH                        -0.682978          0.234937    -0.541904       -0.085652  -0.265026             0.070377             -0.066495 -0.341699  1.000000  -0.196648  0.205633 -0.057731
# sulphates                  0.183006         -0.260987     0.312770        0.005527   0.371260             0.051658              0.042947  0.148506 -0.196648   1.000000  0.093595  0.251397
# alcohol                   -0.061668         -0.202288     0.109903        0.042075  -0.221141            -0.069408             -0.205654 -0.496180  0.205633   0.093595  1.000000  0.476166
# quality                    0.124052         -0.390558     0.226373        0.013732  -0.128907            -0.050656             -0.185100 -0.174919 -0.057731   0.251397  0.476166  1.000000
# </div>

# %%
df.head() #the first row
df.describe().show() #show row, mean, std but unable to read
df.dropna().count() #Return new df omitting rows with null values
df.na.fill(-1).show(5) #Replace null values
spark.stop()

# %%
display(df.groupBy("quality").avg("fixed acidity").orderBy("quality"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>quality</th><th>avg(fixed acidity)</th></tr></thead><tbody><tr><td>3</td><td>8.36</td></tr><tr><td>4</td><td>7.779245283018868</td></tr><tr><td>5</td><td>8.167254038179149</td></tr><tr><td>6</td><td>8.347178683385575</td></tr><tr><td>7</td><td>8.872361809045225</td></tr><tr><td>8</td><td>8.566666666666665</td></tr></tbody></table></div>

# %%
display(df.groupBy("quality").avg("volatile acidity").orderBy("quality"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>quality</th><th>avg(volatile acidity)</th></tr></thead><tbody><tr><td>3</td><td>0.8845000000000001</td></tr><tr><td>4</td><td>0.6939622641509429</td></tr><tr><td>5</td><td>0.5770411160058732</td></tr><tr><td>6</td><td>0.49748432601880965</td></tr><tr><td>7</td><td>0.4039195979899498</td></tr><tr><td>8</td><td>0.4233333333333334</td></tr></tbody></table></div>

# %%
display(df.groupBy("quality").avg("citric acid").orderBy("quality"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>quality</th><th>avg(citric acid)</th></tr></thead><tbody><tr><td>3</td><td>0.17099999999999999</td></tr><tr><td>4</td><td>0.1741509433962264</td></tr><tr><td>5</td><td>0.24368575624082198</td></tr><tr><td>6</td><td>0.2738244514106587</td></tr><tr><td>7</td><td>0.37517587939698493</td></tr><tr><td>8</td><td>0.39111111111111113</td></tr></tbody></table></div>

# %%
display(df.groupBy("quality").avg("residual sugar").orderBy("quality"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>quality</th><th>avg(residual sugar)</th></tr></thead><tbody><tr><td>3</td><td>2.6350000000000002</td></tr><tr><td>4</td><td>2.69433962264151</td></tr><tr><td>5</td><td>2.528854625550658</td></tr><tr><td>6</td><td>2.477194357366772</td></tr><tr><td>7</td><td>2.7206030150753793</td></tr><tr><td>8</td><td>2.5777777777777775</td></tr></tbody></table></div>

# %%
display(df.groupBy("quality").avg("chlorides").orderBy("quality"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>quality</th><th>avg(chlorides)</th></tr></thead><tbody><tr><td>3</td><td>0.12250000000000001</td></tr><tr><td>4</td><td>0.09067924528301885</td></tr><tr><td>5</td><td>0.09273568281938328</td></tr><tr><td>6</td><td>0.08495611285266458</td></tr><tr><td>7</td><td>0.07658793969849244</td></tr><tr><td>8</td><td>0.06844444444444445</td></tr></tbody></table></div>

# %%
display(df.groupBy("quality").avg("total sulfur dioxide").orderBy("quality"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>quality</th><th>avg(total sulfur dioxide)</th></tr></thead><tbody><tr><td>3</td><td>24.9</td></tr><tr><td>4</td><td>36.24528301886792</td></tr><tr><td>5</td><td>56.51395007342144</td></tr><tr><td>6</td><td>40.86990595611285</td></tr><tr><td>7</td><td>35.02010050251256</td></tr><tr><td>8</td><td>33.44444444444444</td></tr></tbody></table></div>

# %%
display(df.groupBy("quality").avg("density").orderBy("quality"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>quality</th><th>avg(density)</th></tr></thead><tbody><tr><td>3</td><td>0.9974640000000001</td></tr><tr><td>4</td><td>0.9965424528301888</td></tr><tr><td>5</td><td>0.9971036270190888</td></tr><tr><td>6</td><td>0.9966150626959255</td></tr><tr><td>7</td><td>0.9961042713567828</td></tr><tr><td>8</td><td>0.9952122222222223</td></tr></tbody></table></div>

# %%
display(df.groupBy("quality").avg("pH").orderBy("quality"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>quality</th><th>avg(pH)</th></tr></thead><tbody><tr><td>3</td><td>3.3979999999999997</td></tr><tr><td>4</td><td>3.381509433962264</td></tr><tr><td>5</td><td>3.3049486049926546</td></tr><tr><td>6</td><td>3.3180721003134837</td></tr><tr><td>7</td><td>3.290753768844219</td></tr><tr><td>8</td><td>3.2672222222222214</td></tr></tbody></table></div>

# %%
display(df.groupBy("quality").avg("sulphates").orderBy("quality"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>quality</th><th>avg(sulphates)</th></tr></thead><tbody><tr><td>3</td><td>0.5700000000000001</td></tr><tr><td>4</td><td>0.5964150943396227</td></tr><tr><td>5</td><td>0.6209691629955947</td></tr><tr><td>6</td><td>0.6753291536050158</td></tr><tr><td>7</td><td>0.7412562814070353</td></tr><tr><td>8</td><td>0.7677777777777778</td></tr></tbody></table></div>

# %%
display(df.groupBy("quality").avg("alcohol").orderBy("quality"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>quality</th><th>avg(alcohol)</th></tr></thead><tbody><tr><td>3</td><td>9.955000000000002</td></tr><tr><td>4</td><td>10.265094339622639</td></tr><tr><td>5</td><td>9.899706314243753</td></tr><tr><td>6</td><td>10.629519331243463</td></tr><tr><td>7</td><td>11.465912897822443</td></tr><tr><td>8</td><td>12.094444444444443</td></tr></tbody></table></div>

# %%
# Convert to float format
def string_to_float(x):
    return float(x)

#catelogy the data
def catelogy(r):
    if (0<= r <= 6.5):
        label = "bad"
    elif(6.5 < r <= 10):
        label = "good"
    else:
        label = "n/a"
    return label
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType, DoubleType

string_to_float_udf = udf(string_to_float, DoubleType())
quality_udf = udf(lambda x: catelogy(x), StringType())

df = df.withColumn("quality", quality_udf("quality"))
df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+----------------+-----------+--------------+---------+-------------------+--------------------+-------+----+---------+-------+-------+
# fixed acidity|volatile acidity|citric acid|residual sugar|chlorides|free sulfur dioxide|total sulfur dioxide|density|  pH|sulphates|alcohol|quality|
# +-------------+----------------+-----------+--------------+---------+-------------------+--------------------+-------+----+---------+-------+-------+
#           7.4|             0.7|        0.0|           1.9|    0.076|               11.0|                34.0| 0.9978|3.51|     0.56|    9.4|    bad|
#           7.8|            0.88|        0.0|           2.6|    0.098|               25.0|                67.0| 0.9968| 3.2|     0.68|    9.8|    bad|
#           7.8|            0.76|       0.04|           2.3|    0.092|               15.0|                54.0|  0.997|3.26|     0.65|    9.8|    bad|
#          11.2|            0.28|       0.56|           1.9|    0.075|               17.0|                60.0|  0.998|3.16|     0.58|    9.8|    bad|
#           7.4|             0.7|        0.0|           1.9|    0.076|               11.0|                34.0| 0.9978|3.51|     0.56|    9.4|    bad|
# +-------------+----------------+-----------+--------------+---------+-------------------+--------------------+-------+----+---------+-------+-------+
# only showing top 5 rows
#
# </div>

# %%
from pyspark.ml.linalg import Vectors
from pyspark.ml import Pipeline
from pyspark.ml.feature import IndexToString,StringIndexer, VectorIndexer
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
    
def transData(data):
    return data.rdd.map(lambda r: [Vectors.dense(r[:-1]),r[-1]]).toDF(['features','label'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
transformed = transData(df)
transformed.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----+
#             features|label|
# +--------------------+-----+
# [7.4,0.7,0.0,1.9,...|  bad|
# [7.8,0.88,0.0,2.6...|  bad|
# [7.8,0.76,0.04,2....|  bad|
# [11.2,0.28,0.56,1...|  bad|
# [7.4,0.7,0.0,1.9,...|  bad|
# +--------------------+-----+
# only showing top 5 rows
#
# </div>

# %%
labelIndexer = StringIndexer(inputCol='label',
                             outputCol='indexedLabel').fit(transformed)
labelIndexer.transform(transformed).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----+------------+
#             features|label|indexedLabel|
# +--------------------+-----+------------+
# [7.4,0.7,0.0,1.9,...|  bad|         0.0|
# [7.8,0.88,0.0,2.6...|  bad|         0.0|
# [7.8,0.76,0.04,2....|  bad|         0.0|
# [11.2,0.28,0.56,1...|  bad|         0.0|
# [7.4,0.7,0.0,1.9,...|  bad|         0.0|
# +--------------------+-----+------------+
# only showing top 5 rows
#
# </div>

# %%
featureIndexer =VectorIndexer(inputCol="features", \
                                  outputCol="indexedFeatures", \
                                  maxCategories=4).fit(transformed)
featureIndexer.transform(transformed).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----+--------------------+
#             features|label|     indexedFeatures|
# +--------------------+-----+--------------------+
# [7.4,0.7,0.0,1.9,...|  bad|[7.4,0.7,0.0,1.9,...|
# [7.8,0.88,0.0,2.6...|  bad|[7.8,0.88,0.0,2.6...|
# [7.8,0.76,0.04,2....|  bad|[7.8,0.76,0.04,2....|
# [11.2,0.28,0.56,1...|  bad|[11.2,0.28,0.56,1...|
# [7.4,0.7,0.0,1.9,...|  bad|[7.4,0.7,0.0,1.9,...|
# +--------------------+-----+--------------------+
# only showing top 5 rows
#
# </div>

# %%
#TODO
from pyspark.ml.feature import PCA
data = transformed
pca = PCA(k=6, inputCol="features", outputCol="pcaFeatures")
model = pca.fit(data)

result = model.transform(data).select("pcaFeatures")
result.show(truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------------------------------------------------------------------------------------------------------------+
# pcaFeatures                                                                                                            |
# +-----------------------------------------------------------------------------------------------------------------------+
# [35.49124147515527,-3.2763380354710465,-7.095489618128157,-1.3928205763352237,9.867294360713043,-1.7897635627976032]   |
# [70.75387009310751,-9.70855940373889,-7.9119321604178605,-1.5921160190041461,10.395573988027593,-1.8930709736714033]   |
# [55.87881981437535,-2.7987769891712784,-7.6404418510039775,-1.572984481455528,10.399749830161705,-1.7968596775840815]  |
# [62.14620931345657,-3.3491156997311684,-10.856349686043936,-0.21799436353226986,10.888877648104138,-1.5026542798311495]|
# [35.49124147515527,-3.2763380354710465,-7.095489618128157,-1.3928205763352237,9.867294360713043,-1.7897635627976032]   |
# [41.7821462181671,-3.9123360898361934,-7.101033097644097,-1.231954020451675,9.932814918121869,-1.7686333064364608]     |
# [60.75297480765876,-1.6884623225141393,-7.550673241847172,-0.7881507700701464,10.197624643701346,-1.7710015505358725]  |
# [23.673588441590613,-10.02630983999775,-6.884493622673721,-0.8424767424183938,10.40024837999694,-1.8056981368724903]   |
# [19.440448288282745,-4.821182255710287,-7.4960616942688905,-1.5026943360356881,9.84131024042117,-1.6952413325183409]   |
# [103.179313972424,5.6990785243508135,-8.383869529729429,-5.1372510536933,10.891735657881865,-1.4185582581516014]       |
# [66.61742621408771,-0.40291175687529623,-6.468284981178903,-1.230146936694102,9.91405744562012,-1.6008180403040222]    |
# [103.179313972424,5.6990785243508135,-8.383869529729429,-5.1372510536933,10.891735657881865,-1.4185582581516014]       |
# [60.982692838859535,-2.7270797819132007,-5.33495054795589,-1.48149630623523,10.45423610912001,-1.6649501243594986]     |
# [30.17230239439504,-2.4022135117140575,-7.428822022762715,-0.9909503623714313,9.666327588146908,-1.0684801858948616]   |
# [152.7733728372274,-18.943511787528617,-9.797640354714462,-1.4252363015482168,10.31970460740683,-1.6416937462928416]   |
# [155.4824252199752,-17.312643504282,-9.801263665418295,-1.528555115175209,10.34265701681069,-1.6142006030216345]       |
# [108.05105636935225,-11.564648610172224,-8.526080216571481,-0.42685449700124356,11.63341233572112,-1.3060371925657117] |
# [58.045346753291184,-3.3145838212911016,-7.843341814639305,-0.7879789348465469,10.087919873881056,-1.1974241056649477] |
# [29.54272167068596,0.48388277789236067,-7.7356241466456055,-3.7937304512416237,9.027297439457522,-1.6407831279247191]  |
# [58.2668508230625,-4.293724652308057,-7.730066835035479,-0.8903740686710475,9.959120092618459,-0.9848991067458218]     |
# +-----------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows
#
# </div>

# %%
(trainingData, testData) = transformed.randomSplit([0.8, 0.2])
print("Training Dataset Count: " + str(trainingData.count()))
print("Test Dataset Count: " + str(testData.count()))
trainingData.show(5)
testData.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Training Dataset Count: 1292
# Test Dataset Count: 307
# +--------------------+-----+
#             features|label|
# +--------------------+-----+
# [4.7,0.6,0.17,2.3...|  bad|
# [4.9,0.42,0.0,2.1...| good|
# [5.0,0.38,0.01,1....|  bad|
# [5.0,0.4,0.5,4.3,...|  bad|
# [5.0,0.42,0.24,2....| good|
# +--------------------+-----+
# only showing top 5 rows
#
# +--------------------+-----+
#             features|label|
# +--------------------+-----+
# [4.6,0.52,0.15,2....|  bad|
# [5.3,0.57,0.01,1....| good|
# [5.4,0.42,0.27,2....| good|
# [5.4,0.74,0.09,1....|  bad|
# [5.6,0.66,0.0,2.2...| good|
# +--------------------+-----+
# only showing top 5 rows
#
# </div>

# %%
from pyspark.ml.classification import DecisionTreeClassifier

# Train a DecisionTree model
dTree = DecisionTreeClassifier(labelCol='indexedLabel', featuresCol='indexedFeatures')
# Convert indexed labels back to original labels.
labelConverter = IndexToString(inputCol="prediction", 
                               outputCol="predictedLabel",
                               labels=labelIndexer.labels)
# Chain indexers and tree in a Pipeline
pipeline = Pipeline(stages=[labelIndexer, featureIndexer, dTree,labelConverter])
# Train model.  This also runs the indexers.
model = pipeline.fit(trainingData)



# Make predictions.
predictions = model.transform(testData)
# Select example rows to display.
predictions.select("features","label","predictedLabel").show(5)



from pyspark.ml.evaluation import MulticlassClassificationEvaluator
# Select (prediction, true label) and compute test error
evaluator = MulticlassClassificationEvaluator(labelCol="indexedLabel", 
                                              predictionCol="prediction", 
                                              metricName="accuracy")
accuracy = evaluator.evaluate(predictions)
print("Test Error = %g" % (1.0 - accuracy))

rfModel = model.stages[-2]
print(rfModel)  # summary only
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansigreen">&lt;command-3676866885536872&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">     30</span> rfModel <span class="ansiyellow">=</span> model<span class="ansiyellow">.</span>stages<span class="ansiyellow">[</span><span class="ansiyellow">-</span><span class="ansicyan">2</span><span class="ansiyellow">]</span><span class="ansiyellow"></span>
# <span class="ansigreen">     31</span> print<span class="ansiyellow">(</span>rfModel<span class="ansiyellow">)</span>  <span class="ansired"># summary only</span><span class="ansiyellow"></span>
# <span class="ansigreen">---&gt; 32</span><span class="ansiyellow"> </span>model<span class="ansiyellow">.</span>summary<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">AttributeError</span>: &apos;PipelineModel&apos; object has no attribute &apos;summary&apos;</div>

# %%
from pyspark.ml.classification import RandomForestClassifier

# Train a RandomForest model.
rf = RandomForestClassifier(labelCol="indexedLabel", featuresCol="indexedFeatures", numTrees=10)

# Convert indexed labels back to original labels.
labelConverter = IndexToString(inputCol="prediction", 
                               outputCol="predictedLabel",
                               labels=labelIndexer.labels)
# Chain indexers and tree in a Pipeline
pipeline = Pipeline(stages=[labelIndexer, featureIndexer, rf,labelConverter])
# Train model.  This also runs the indexers.
model = pipeline.fit(trainingData)

# Make predictions.
predictions = model.transform(testData)
# Select example rows to display.
predictions.select("features","label","predictedLabel").show(5)


from pyspark.ml.evaluation import MulticlassClassificationEvaluator
# Select (prediction, true label) and compute test error
evaluator = MulticlassClassificationEvaluator(labelCol="indexedLabel", 
                                              predictionCol="prediction", 
                                              metricName="accuracy")
accuracy = evaluator.evaluate(predictions)
print("Test Error = %g" % (1.0 - accuracy))

rfModel = model.stages[-2]
print(rfModel)  # summary only
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----+--------------+
#             features|label|predictedLabel|
# +--------------------+-----+--------------+
# [5.1,0.47,0.02,1....|  bad|           bad|
# [5.2,0.32,0.25,1....|  bad|           bad|
# [5.2,0.34,0.0,1.8...|  bad|           bad|
# [5.2,0.645,0.0,2....|  bad|           bad|
# [5.4,0.74,0.09,1....|  bad|           bad|
# +--------------------+-----+--------------+
# only showing top 5 rows
#
# Test Error = 0.110429
# RandomForestClassificationModel (uid=RandomForestClassifier_729da6d7901e) with 10 trees
# </div>

# %%
from pyspark.ml.classification import NaiveBayes
nb = NaiveBayes(featuresCol='indexedFeatures', 
                labelCol='indexedLabel')

# Convert indexed labels back to original labels.
labelConverter = IndexToString(inputCol="prediction", 
                               outputCol="predictedLabel",
                               labels=labelIndexer.labels)
# Chain indexers and tree in a Pipeline
pipeline = Pipeline(stages=[labelIndexer, featureIndexer, nb,labelConverter])
# Train model.  This also runs the indexers.
model = pipeline.fit(trainingData)

# Make predictions.
predictions = model.transform(testData)
# Select example rows to display.
predictions.select("features","label","predictedLabel").show(5)

from pyspark.ml.evaluation import MulticlassClassificationEvaluator
# Select (prediction, true label) and compute test error
evaluator = MulticlassClassificationEvaluator(labelCol="indexedLabel", 
                                              predictionCol="prediction", 
                                              metricName="accuracy")
accuracy = evaluator.evaluate(predictions)
print(accuracy)
print("Test Error = %g" % (1.0 - accuracy))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----+--------------+
#             features|label|predictedLabel|
# +--------------------+-----+--------------+
# [4.6,0.52,0.15,2....|  bad|           bad|
# [5.3,0.57,0.01,1....| good|           bad|
# [5.4,0.42,0.27,2....| good|           bad|
# [5.4,0.74,0.09,1....|  bad|           bad|
# [5.6,0.66,0.0,2.2...| good|          good|
# +--------------------+-----+--------------+
# only showing top 5 rows
#
# 0.7100977198697068
# Test Error = 0.289902
# </div>

# %%
from pyspark.ml.classification import LinearSVC

svm = LinearSVC(featuresCol='indexedFeatures', 
                labelCol='indexedLabel')
# Convert indexed labels back to original labels.
labelConverter = IndexToString(inputCol="prediction", 
                               outputCol="predictedLabel",
                               labels=labelIndexer.labels)
# Chain indexers and tree in a Pipeline
pipeline = Pipeline(stages=[labelIndexer, featureIndexer, svm,labelConverter])
# Train model.  This also runs the indexers.
model = pipeline.fit(trainingData)

# Make predictions.
predictions = model.transform(testData)
# Select example rows to display.
predictions.select("features","label","predictedLabel").show(5)

from pyspark.ml.evaluation import MulticlassClassificationEvaluator
# Select (prediction, true label) and compute test error
evaluator = MulticlassClassificationEvaluator(labelCol="indexedLabel", 
                                              predictionCol="prediction", 
                                              metricName="accuracy")
accuracy = evaluator.evaluate(predictions)
print(accuracy)
print("Test Error = %g" % (1.0 - accuracy))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----+--------------+
#             features|label|predictedLabel|
# +--------------------+-----+--------------+
# [4.6,0.52,0.15,2....|  bad|           bad|
# [5.3,0.57,0.01,1....| good|           bad|
# [5.4,0.42,0.27,2....| good|           bad|
# [5.4,0.74,0.09,1....|  bad|           bad|
# [5.6,0.66,0.0,2.2...| good|           bad|
# +--------------------+-----+--------------+
# only showing top 5 rows
#
# 0.8631921824104235
# Test Error = 0.136808
# </div>
